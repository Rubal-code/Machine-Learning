# %% [markdown]
# <a href="https://colab.research.google.com/github/Rubal-code/Machine-Learning/blob/main/Spacy_POS-TAGGING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy

# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")

# %%
doc = nlp(u"I will google about facebook")

# %%
doc.text
# Out:
# 'I will google about facebook'

# %%
doc[2].pos_
# Out:
# 'VERB'

# %%
doc[2].tag_
# Out:
# 'VB'

# %%
spacy.explain('VB')
# Out:
# 'verb, base form'

# %%
for word in doc:
    print(word.text,"------>", word.pos_,word.tag_,spacy.explain(word.tag_))
# Out:
# I ------> PRON PRP pronoun, personal
# will ------> AUX MD verb, modal auxiliary
# google ------> VERB VB verb, base form
# about ------> ADP IN conjunction, subordinating or preposition
# facebook ------> PROPN NNP noun, proper singular

# %%
from spacy import displacy

# %%
displacy.render(doc,style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="eb6ee43cb42e467cb93c44864c83d34a-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
options={
    'distance':80,
    'compact':True,
    'color':'#fff',
    'bg':'#00a65a'
}

# %%
displacy.render(doc,style='dep',jupyter=True,options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c96bacfbb1f4493394465b4a503dff78-0" class="displacy" width="450" height="217.0" direction="ltr" style="max-width: none; height: 217.0px; color: #fff; background: #00a65a; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="127.0">
# ...
