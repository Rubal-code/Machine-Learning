# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('play_tennis.csv')
df.drop(columns=['day'],inplace=True)

# %%
df.head()
# Out:
#     outlook  temp humidity    wind play
# 0     Sunny   Hot     High    Weak   No
# 1     Sunny   Hot     High  Strong   No
# 2  Overcast   Hot     High    Weak  Yes
# 3      Rain  Mild     High    Weak  Yes
# 4      Rain  Cool   Normal    Weak  Yes

# %%
# problem 1

# outlook = sunny, ,temp= hot, humidity = high, wind=weak

# play or not?

# %%
# solution

# P(play=yes|sunny,hot,high,weak)=P(sunny|yes)*P(hot|yes)*P(high|yes)*P(weak|yes)

# P(play=no|sunny,hot,high,weak)=P(sunny|no)*P(hot|no)*P(high|no)*P(weak|no)

# %%
# problem 2

# outlook = overcast, ,temp= cold, humidity = low, wind=weak

# play or not?

# %%
# solution
# P(play=yes|overcast,cold,low,weak)=P(overcast|yes)*P(cold|yes)*P(low|yes)*P(weak|yes)
# P(play=no|overcast,cold,low,weak)=P(overcast|no)*P(cold|no)*P(low|no)*P(weak|no)

# compare and decide with maximum posterior probability rule

# %%
# training

# lookup table 

# testing

# %%
# P(yes)
# P(no)

# %%
df['play'].value_counts()
# Out:
# play
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
py=(9/14)
pn=(5/14)

# %%
print(py,pn)
# Out:
# 0.6428571428571429 0.35714285714285715

# %%
# outlook
pd.crosstab(df['outlook'],df['play'])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
pon=0
prn=2/5
psn=3/5

poy=4/9
pry=3/9
psy=2/9

# %%
# temp
pd.crosstab(df['temp'],df['play'])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
pcn=1/5
phn=2/5
pmn=2/5

pcy=3/9
phy=2/9
pmy=4/9

# %%
# humidity
pd.crosstab(df['humidity'],df['play'])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
phn=4/5
pnn=1/5

phy=3/9
pny=6/9

# %%
# wind
pd.crosstab(df['wind'],df['play'])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
psn=3/5
pwn=2/5

psy=3/9
pwy=6/9

# %%
# py* poy*pmy*psy*pwy
