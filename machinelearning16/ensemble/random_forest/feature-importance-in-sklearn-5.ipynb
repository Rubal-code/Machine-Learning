# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=load_breast_cancer()
df=pd.DataFrame(data.data,columns=data.feature_names)
df['target']=data.target

# %%
df
# Out:
#      mean radius  mean texture  ...  worst fractal dimension  target
# 0          17.99         10.38  ...                  0.11890       0
# 1          20.57         17.77  ...                  0.08902       0
# 2          19.69         21.25  ...                  0.08758       0
# 3          11.42         20.38  ...                  0.17300       0
# 4          20.29         14.34  ...                  0.07678       0
# ..           ...           ...  ...                      ...     ...
# 564        21.56         22.39  ...                  0.07115       0
# 565        20.13         28.25  ...                  0.06637       0
# 566        16.60         28.08  ...                  0.07820       0
# 567        20.60         29.33  ...                  0.12400       0
# 568         7.76         24.54  ...                  0.07039       1
#
# [569 rows x 31 columns]

# %%
X = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
sns.heatmap(X.iloc[5].values.reshape(5,6))
# Out:
# <Axes: >

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

rf.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
rf.feature_importances_
# Out:
# array([0.02847006, 0.01309235, 0.04473084, 0.04806693, 0.00779893,
#        0.0142437 , 0.04065116, 0.11761755, 0.00345839, 0.00514389,
#        0.01255474, 0.00495775, 0.01477948, 0.02487231, 0.00366971,
#        0.00656377, 0.00569389, 0.00233382, 0.00335628, 0.00446989,
#        0.15427558, 0.01545525, 0.09900558, 0.10812201, 0.011406  ,
#        0.01845176, 0.04501688, 0.1222876 , 0.0130126 , 0.00644128])

# %%
rf.feature_importances_.shape
# Out:
# (30,)

# %%
sns.heatmap(rf.feature_importances_.reshape(5,6))
# Out:
# <Axes: >
